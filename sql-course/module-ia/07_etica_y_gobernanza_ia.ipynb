# %% [markdown]
# ## Principios Fundamentales
#
# ### 1️⃣ Privacidad de Datos
# - ❌ **NO compartir**: datos productivos reales, PII (emails, nombres, identificaciones), credenciales de BD
# - ✅ **SÍ compartir**: esquemas anonimizados, datos sintéticos, estructura de tablas sin contenido sensible
# - **Ejemplo seguro**: "Genera consulta para tabla `clientes` con columnas `cliente_id`, `ciudad`, `fecha_registro`" (sin datos reales)
#
# ### 2️⃣ Validación Obligatoria
# - ❌ **NO copiar y pegar** código de IA directamente a producción sin revisión
# - ✅ **SÍ validar**: ejecutar en ambiente dev, verificar resultados con casos de prueba, peer review humano
# - **Regla**: código generado por IA = código de junior que necesita supervisión
#
# ### 3️⃣ Atribución y Transparencia
# - Documentar en comentarios si código complejo fue asistido por IA: `-- Generado con asistencia de IA (Copilot) - validado el 2024-06-15`
# - En proyectos open-source, revisar licencias de código sugerido por IA
# - Comunicar a equipo cuando IA es parte del workflow de desarrollo
#
# ### 4️⃣ Límites de la IA
# - IA **NO conoce**: lógica de negocio específica de tu empresa, datos actualizados post-2023, planes de ejecución reales de tu BD
# - IA **puede alucinar**: generar sintaxis incorrecta, sugerir funciones inexistentes, asumir esquemas erróneos
# - **Responsabilidad final**: siempre del desarrollador, no de la herramienta
#
# ### 5️⃣ Gobernanza en Equipos
# - Establecer políticas claras: qué datos pueden compartirse con IA, qué herramientas están aprobadas
# - Capacitación obligatoria en prompting efectivo y validación de código
# - Auditorías periódicas de código generado por IA (revisar commits, SPs críticos)
#
# ---
#
# ## 🟢 Ejercicio Básico
# Identifica qué prompts son seguros vs. inseguros:
# - "Genera SELECT para tabla usuarios con columnas user_id, email" → ¿Seguro?
# - "Analiza estos 1000 registros de clientes: [datos reales]" → ¿Seguro?
#
# ## 🟠 Ejercicio Intermedio
# Diseña checklist de validación para código SQL generado por IA antes de merge a main.
#
# ## 🔴 Ejercicio Avanzado
# Elabora política de gobernanza de IA para equipo de 10 desarrolladores (qué se permite, qué no, proceso de revisión).
#
# ---
#
# ## Errores Comunes en Uso Ético de IA
# - Compartir datos sensibles sin anonimizar: riesgo GDPR, compliance
# - Confiar ciegamente en IA: "si Copilot lo sugiere, debe ser correcto" → ❌
# - No documentar origen: código de IA sin comentarios dificulta mantenimiento futuro
# - Usar IA para bypasear estándares: generar código rápido pero que rompe convenciones del equipo
#
# ---
#
# ## Recursos
# - [Microsoft Responsible AI Principles](https://www.microsoft.com/ai/responsible-ai)
# - [GitHub Copilot Trust Center](https://github.com/features/copilot)
# - GDPR Guidelines for AI-assisted Development

# %% [markdown]
# # 4.7 Ética y Gobernanza en el Uso de IA para SQL
#
# - Objetivo: establecer principios éticos y buenas prácticas al usar IA en desarrollo SQL.
# - Prerrequisitos: experiencia usando asistentes de IA.
# - Temas clave: privacidad de datos, atribución de código, validación obligatoria, límites de IA.
# - Aplicaciones: políticas de equipo, compliance, formación de desarrolladores.

# %% [markdown]
# # Créditos
#
# Este material fue revisado y enriquecido parcialmente mediante asistencia de IA (OpenAI y Claude); la validación y decisiones editoriales finales son humanas.

# %% [markdown]
# ---
# ## Navegación
# [⬅️ Anterior](06_revision_ai_pair_programming.ipynb)
# ---
