# %% [markdown]
# ## Ejemplo Práctico
#
# **Prompt sugerido:**
# ```
# Explica línea por línea esta consulta SQL:
#
# SELECT c.nombre, SUM(v.cantidad) AS total_ventas
# FROM dbo.fact_ventas v
# JOIN dbo.dim_clientes c ON v.cliente_id = c.cliente_id
# WHERE v.fecha >= '2024-01-01'
# GROUP BY c.nombre
# HAVING SUM(v.cantidad) > 100
# ORDER BY total_ventas DESC;
# ```
#
# **Respuesta esperada de la IA:**
# 1. `SELECT c.nombre, SUM(v.cantidad) AS total_ventas`: proyecta nombre cliente y suma de cantidad vendida
# 2. `FROM dbo.fact_ventas v JOIN dbo.dim_clientes c ON v.cliente_id = c.cliente_id`: combina fact_ventas con dim_clientes
# 3. `WHERE v.fecha >= '2024-01-01'`: filtra ventas desde 1 enero 2024
# 4. `GROUP BY c.nombre`: agrupa por nombre de cliente
# 5. `HAVING SUM(v.cantidad) > 100`: solo clientes con más de 100 unidades
# 6. `ORDER BY total_ventas DESC`: ordena por ventas descendente
#
# ---
#
# ## 🟢 Ejercicio Básico
# Solicita a la IA explicar este CTE:
# ```sql
# WITH RankedProducts AS (
#   SELECT producto_id, SUM(cantidad) AS total,
#          ROW_NUMBER() OVER(ORDER BY SUM(cantidad) DESC) AS rank
#   FROM dbo.fact_ventas GROUP BY producto_id
# )
# SELECT * FROM RankedProducts WHERE rank <= 5;
# ```
#
# ## 🟠 Ejercicio Intermedio
# Pide a la IA comparar dos consultas (una con INNER JOIN y otra con subquery) y que explique cuál es más eficiente.
#
# ## 🔴 Ejercicio Avanzado
# Solicita explicación de una consulta con múltiples CTEs y WINDOW functions para análisis de cohortes.
#
# ---
#
# ## Errores Comunes
# - No proporcionar esquema de tablas: IA puede asumir estructura incorrecta
# - Consultas demasiado largas: mejor dividir en secciones
# - No validar respuesta: verificar con ejecución real

# %% [markdown]
# # 4.2 Explicación de SQL con IA
#
# - Objetivo: usar herramientas de IA para interpretar queries complejos (JOINs, CTEs, subqueries).
# - Prerrequisitos: conocimientos básicos de SQL.
# - Método: copiar consulta SQL y solicitar explicación línea por línea a la IA.
# - Aplicaciones: onboarding de nuevo código, debugging, aprendizaje de patrones desconocidos.
