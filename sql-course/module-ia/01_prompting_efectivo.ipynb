# %% [markdown]
# # 4.1 Prompting Efectivo
#
# - Objetivo: diseñar prompts claros para generar/explicar SQL.
# - Prerrequisitos: conocer el esquema (dim_*/fact_*).
# - Ejercicios: plantillas de prompt; contexto mínimo; criterios de aceptación.
# - Reto: prompt robusto anti-alucinación.
# - Errores comunes: vaguedad, falta de contexto, pedir múltiples tareas sin estructura.
#
# ---
#
# ## Elementos clave de un buen prompt
#
# 1. **Contexto del esquema**: incluir DDL o descripción de tablas relevantes.
# 2. **Objetivo claro**: qué métrica o análisis se requiere.
# 3. **Restricciones**: filtros, ordenamiento, formato de salida.
# 4. **Criterios de aceptación**: cómo validar que el resultado es correcto.
#
# ---
#
# ## Ejemplo de prompt efectivo
#
# ```
# Genera consulta SQL (T-SQL) que calcule ventas totales y margen por producto
# usando tablas dbo.fact_ventas y dbo.dim_productos.
#
# Esquema:
# - fact_ventas (venta_id, fecha, cliente_id, producto_id, cantidad, descuento_pct)
# - dim_productos (producto_id PK, nombre, precio_unitario, costo_unitario, categoria)
#
# Requisitos:
# - Agrupar por producto_id y nombre.
# - Ordenar por margen descendente.
# - Excluir productos sin ventas.
# ```
#
# ---
#
# 🟢 Ejercicio: Escribe prompt para calcular ticket promedio por región.
#
# 🟠 Ejercicio: Prompt para explicar una consulta con CTE y window function.
#
# 🔴 Reto: Prompt que solicite validación de calidad de datos (nulos, rangos) con umbrales específicos.
